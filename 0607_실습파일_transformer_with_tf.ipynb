# %% [markdown]
# # 트랜스포머 (Transformer)
#
# * 참고: https://wikidocs.net/31379 , www.suanlab.com
# * 깃허브 링크 : https://github.com/ukairia777/tensorflow-transformer

# %% [markdown]
# * attention mechanism은 seq2seq의 입력 시퀀스 정보 손실을 보정해주기 위해 사용됨
# * attention mechanism을 보정 목적이 아닌, 인코더와 디코더로 구성한 모델이 바로 트랜스포머
# * 트랜스포머는 RNN을 사용하지 않고 인코더와 디코더를 설계하였으며, 성능도 RNN보다 우수함

# %% [markdown]
# ## 포지셔널 인코딩

# %% [markdown]
# * 기존의 RNN은 단어의 위치를 따라 순차적으로 입력받아 단어의 위치정보를 활용할 수 있었음
# * 트랜스포머의 경우, RNN을 활용하지 않았기 때문에 단어의 위치정보를 다른 방식으로 줄 필요가 있음
# * 이를 위해 **각 단어의 임베딩 벡터에 위치 정보들을 더하게 되는데** 이를 포지셔널 인코딩이라 함
# * 보통 포지셔널 인코딩은 sin, cos을 이용하여 계산

# %%
def positional_encoding(dim, sentence_length): 
  encoded_vec = np.array([pos / np.power(10000, 2 * i / dim) for pos in range(sentence_length) for i in range(dim)])
  encoded_vec[::2] = np.sin(encoded_vec[::2])
  encoded_vec[1::2] = np.cos(encoded_vec[1::2])
  return tf.constant(encoded_vec.reshape([sentence_length, dim]), dtype = tf.float32)

# %% [markdown]
# ## 레이어 정규화

# %% [markdown]
# *  레이어 정규화에서는 텐서의 마지막 차원에 대해 평균과 분산을 구하고, 이 값을 통해 값을 정규화함
# *  해당 정규화를 각 층의 연결에 편리하게 적용하기 위해 함수화한 `sublayer_connection()`을 선언

# %%
def layer_norm(inputs, eps=1e-6):
  feature_shape = inputs.get_shape()[-1:]
  mean = tf.keras.backend.mean(inputs, [-1], keepdims=True) 
  std = tf.keras.backend.std(inputs, [-1], keepdims=True)
  beta = tf.Variable(tf.zeros(feature_shape),trainable=True)
  gamma = tf.Variable(tf.zeros(feature_shape),trainable=True)
  return gamma * (inputs - mean) / (std + eps) + beta

# %%
def sublayer_connection(inputs, sublayer, dropout = 0.2) :
  outputs = layer_norm(inputs + tf.keras.layers.Dropout(dropout)(sublayer)) 
  return outputs

# %% [markdown]
# ## 어텐션

# %% [markdown]
# *   트랜스포머 모델의 핵심이 되는 부분
# *   트랜스포머에서는 multi-head attention과 self attention이라는 개념을 사용
#   1.   multi-head attention
#       * 디코더가 가지는 차원을 나누어 병렬로 어텐션을 진행
#       *  마지막엔 병렬로 각 진행해 얻은 어텐션 헤드를 모두 연결
#       * 이로 인해 다양한 시각에서 정보를 수집할 수 있는 효과를 얻음
#   2.   self attention
#       *   일반적인 어텐션의 경우, 특정 시점의 디코더 은닉상태와 모든 시점의 인코더 은닉상태를 활용
#       *   이는 입력 문장과 다른 문장에 존재하는 단어간의 어텐션을 의미함
#       *   반면 self attention은 은닉 상태를 동일하게 하여 어텐션을 진행
#       *   이는 입력 문장 내 단어간의 어텐션을 의미함
#
#
#
#
# *   트랜스포머 제안 논문에서는 scaled-dot product attention을 활용해 모델을 작성함

# %% [markdown]
# ### scaled-dot product attention 구현

# %% [markdown]
# * attention을 진행할 때 어텐션 스코어를 계산할 때 내적 값을 정규화
# * 트랜스포머에서는 정규화할 때 K 벡터(=디코더 셀의 은닉 상태)의 차원을 루트를 취한 값을 사용

# %%
def scaled_dot_procuct_attention(query, key, value, masked=False):
  key_dim_size = float(key.get_shape().as_list()[-1])
  key = tf.transpose(key, perm=[0, 2, 1]) 

  outputs = tf.matmul(query, key) / tf. sqrt(key_dim_size)

  if masked :
    diag_vals = tf.ones_like(outputs[0, :, :]) 
    tril = tf.linalg.LinearOperatorLowerTriangular(diag_vals).to_dense()
    masks = tf.tile(tf.expand_dims(tril,0), [tf.shape(outputs)[0],1,1])
    paddings = tf.ones_like(masks)*(-2**30)
    outputs = tf.where(tf.equal(masks, 0), paddings, outputs) 

  attention_map = tf.nn.softmax(outputs)
  return tf.matmul(attention_map, value)

# %% [markdown]
# ### multi-head attention 구현

# %% [markdown]
# * multi-head attention의 구현 과정
#   1. query, key, value에 해당하는 값을 받고, 해당 값에 해당하는 행렬 생성
#   2. 생성된 행렬들을 heads에 해당하는 수만큼 분리
#   3. 분리한 행렬들에 대해 각각 어텐션을 수행
#   4. 각 어텐션 결과들을 연결해 최종 어텐션 결과 생성

# %%
def multi_head_attention(query, key, value, num_units, heads, masked=False) :
  query = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(query)
  key = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(key)
  value = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(value)
  
  query = tf.concat(tf.split(query, heads, axis=-1), axis=0) 
  key = tf.concat(tf.split(key, heads, axis=-1), axis=0)
  value = tf.concat(tf.split(value, heads, axis=-1), axis=0)

  attention_map = scaled_dot_procuct_attention(query, key, value, masked)
  attn_outputs = tf.concat(tf.split(attention_map, heads, axis=0), axis=-1)
  attn_outputs = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(attn_outputs)

  return attn_outputs

# %% [markdown]
# ## 포지션-와이즈 피드 포워드 신경망

# %% [markdown]
# *   multi-head attention의 결과인 행렬을 입력받아 연산
# *   일반적인 완전 연결 신경망(Dense layer)를 사용
# *   position-wise FFNN은 인코더와 디코더에 모두 존재

# %%
def feed_forward(inputs, num_units):
  feature_shape = inputs.get_shape()[-1]
  inner_layer = tf.keras.layers.Dense(num_units, activation=tf.nn.relu)(inputs)
  outputs = tf.keras.layers.Dense(feature_shape)(inner_layer)
  return outputs

# %% [markdown]
# ## 인코더

# %% [markdown]
# * 인코더는 하나의 어텐션을 사용
#   + encoder self-attention (multi-head self-attention과 동일)

# %%
def encoder_module(inputs, model_dim, ffn_dim, heads):
  self_attn = sublayer_connection(inputs, multi_head_attention(inputs, inputs, inputs, model_dim, heads))
  outputs = sublayer_connection(self_attn, feed_forward(self_attn, ffn_dim))
  return outputs

def encoder(inputs, model_dim, ffn_dim, heads, num_layers):
  outputs = inputs
  for i in range(num_layers):
    outputs = encoder_module(outputs, model_dim, ffn_dim, heads)

  return outputs

# %% [markdown]
# ## 디코더

# %% [markdown]
# * 디코더는 다음과 같은 구성의 반복으로 이루어짐
#   1. masked decoder self-attention
#   2. encoder-decoder attention
#   3. position-wise FFNN
#
# * 디코더에서는 2종류의 어텐션을 사용
#   1.   masked decoder self-attention
#     *   디코더에서는 인코더와는 달리 순차적으로 결과를 만들어 내야하기 때문에 다른 어텐션 방법을 사용함
#     *   디코더 예측 시점 이후의 위치에 attention을 할 수 없도록 masking 처리
#     *   결국 예측 시점에서 예측은 미리 알고 있는 위치까지만의 결과에 의존
#   2.   encoder-decoder attention
#     *   앞서 설명한 multi-head attention과 동일

# %%
def decoder_module(inputs, encoder_outputs, model_dim, ffn_dim, heads):
  masked_self_attn = sublayer_connection(inputs, 
                                         multi_head_attention(inputs, inputs, inputs,
                                                              model_dim, heads, masked=True))
  self_attn = sublayer_connection(masked_self_attn,
                                  multi_head_attention(masked_self_attn,
                                                       encoder_outputs,
                                                       encoder_outputs,
                                                       model_dim, heads))
  
  outputs = sublayer_connection(self_attn, feed_forward(self_attn, ffn_dim))
  return outputs

def decoder(inputs, encoder_outputs, model_dim, ffn_dim, heads, num_layers):
  outputs = inputs
  for i in range(num_layers):
    outputs = decoder_module(outputs, encoder_outputs, model_dim, ffn_dim, heads)

  return outputs

# %% [markdown]
# ## 트랜스포머를 활용한 챗봇

# %% [markdown]
# ### konlpy 라이브러리

# %% [markdown]
# *    한글을 처리하기 위해 konlpy 라이브러리 설치

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.4 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 26.7 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.2.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %% [markdown]
# ### 데이터 준비

# %% [markdown]
# * 처리에 필요한 각종 변수 선언
# * filters에 해당되는 문자를 걸러주는 정규 표현식 컴파일

# %%
import re
import tensorflow as tf

filters = "([~.,!?\"':;)(])"

PAD = '<PADDING>'
STD = '<START>'
END = '<END>'
UNK = '<UNKNOWN>'

PAD_INDEX = 0
STD_INDEX = 1
END_INDEX = 2
UNK_INDEX = 3

MARKER = [PAD, STD, END, UNK]
CHANGE_FILTER = re.compile(filters)

# %% [markdown]
# * 주소에서 데이터를 가져오는 `load_data()` 함수 선언

# %%
from sklearn.model_selection import train_test_split

def load_data(data_path):
  data_df = pd.read_csv(data_path, header=0)
  question, answer = list(data_df['Q']), list(data_df['A'])
  train_input, eval_input, train_label, eval_label = train_test_split(question, answer,
                                                                     test_size = 0.33,
                                                                     random_state = 111)

  return train_input, train_label, eval_input, eval_label

# %% [markdown]
# * 처리에 필요한 단어 사전을 생성하는 `load_vocab()` 함수 선언

# %%
def load_vocab(data_path):
  data_df = pd.read_csv(data_path, encoding = 'utf-8')
  question, answer = list(data_df['Q']), list(data_df['A'])
  
  if tokenize_as_morph:
    question = prepro_like_morphlized(question)
    answer = prepro_like_morphlized(answer)
  
  data =[]
  data.extend(question)
  data.extend(answer)
  words = data_tokenizer(data)
  words = list(set(words))
  words[:0] = MARKER

  char2idx = {char:idx for idx, char in enumerate(words)}
  idx2char = {idx:char for idx, char in enumerate(words)}

  return char2idx, idx2char, len(char2idx)

# %% [markdown]
# * 문자열 데이터를 학습에 사용될 수 있도록 변현하는 `prepro_like_morphlized()` 함수 선언

# %%
from konlpy.tag import Okt 

def prepro_like_morphlized(data):
  morph_analyzer = Okt()
  result_data = list()
  for seq in data:
    morphlized_seq = " ".join(morph_analyzer.morphs(seq.replace(' ',''))) 
    result_data.append(morphlized_seq)
  return result_data

# %% [markdown]
# * 단어 사전을 만들기 위해 단어들을 분리하는 `data_tokenizer()` 함수 선언

# %%
def data_tokenizer(data):
  words=[] 
  for sentence in data :
    sentence = re.sub(CHANGE_FILTER,"",sentence) 
    for word in sentence.split():
      words.append(word)
  return [word for word in words]

# %% [markdown]
# * encoder의 입력을 구성하기 위한 함수 `enc_processing()` 선언

# %%
def enc_processing(value, dictionary) :
  sequences_input_index = []
  sequences_length =[]

  if tokenize_as_morph:
    value = prepro_like_morphlized(value)

  for sequence in value:
    sequence = re.sub(CHANGE_FILTER, "", sequence)
    sequence_index = []
    for word in sequence.split():
      if dictionary.get(word) is not None :
        sequence_index.extend([dictionary[word]])
      else :
        sequence_index.extend([dictionary[UNK]])

    if len(sequence_index) > max_len:
      sequence_index = sequence_index[:max_len]
      
    sequences_length.append(len(sequence_index))
    sequence_index += (max_len - len(sequence_index)) * [dictionary[PAD]]
    sequences_input_index.append(sequence_index)
    
  return np.asarray(sequences_input_index), sequences_length

# %% [markdown]
# * decoder의 입력을 구성하기 위한 함수 `dec_output_processing()` 선언

# %%
def dec_output_processing(value, dictionary) :
  sequences_output_index = []
  sequences_length =[]

  if tokenize_as_morph:
    value = prepro_like_morphlized(value)

  for sequence in value:
    sequence = re.sub(CHANGE_FILTER, "", sequence)
    sequence_index = []
    sequence_index = [dictionary[STD]] + [dictionary[word] for word in sequence.split()]
    if len(sequence_index) > max_len:
      sequence_index = sequence_index[:max_len]
    sequences_length.append(len(sequence_index))
    sequence_index += (max_len - len(sequence_index)) * [dictionary[PAD]]
    sequences_output_index.append(sequence_index)
    
  return np.asarray(sequences_output_index), sequences_length

# %% [markdown]
# * decoder의 출력을 구성하기 위한 함수 `dec_target_processing()` 선언

# %%
def dec_target_processing(value, dictionary, tokenize_as_morph=False) :
  sequences_target_index = []

  if tokenize_as_morph:
    value = prepro_like_morphlized(value)

  for sequence in value:
    sequence = re.sub(CHANGE_FILTER, "", sequence)
    sequence_index = [dictionary[word] if word in dictionary else dictionary[UNK] for word in sequence.split()]
    if len(sequence_index) >= max_len:
      sequence_index = sequence_index[:max_len - 1] + [dictionary[END]]
    else :
      sequence_index += [dictionary[END]]
    sequence_index += (max_len - len(sequence_index)) * [dictionary[PAD]]
    sequences_target_index.append(sequence_index)
  return np.asarray(sequences_target_index)

# %% [markdown]
# * 모델에 데이터를 효율적으로 투입하도록 `train_input_fn()`, `eval_input_fn()` 함수 선언
# * `rearrange()`는 dataset 객체가 데이터를 어떻게 변형시킬지 정의해둔 함수
# * dataset.map은 rearrange 함수를 기반으로 데이터를 변형

# %%
def train_input_fn(train_input_enc, train_output_enc, train_target_dec, batch_size):
  dataset = tf.compat.v1.data.Dataset.from_tensor_slices((train_input_enc, train_output_enc, train_target_dec))
  dataset = dataset.shuffle(buffer_size = len(train_input_enc)) 
  dataset = dataset.batch(batch_size)
  dataset = dataset.map(rearrange)
  dataset = dataset.repeat()
  iterator =dataset.make_one_shot_iterator()
  return iterator.get_next()

def eval_input_fn(eval_input_enc, eval_output_enc, eval_target_dec, batch_size):
  dataset = tf.compat.v1.data.Dataset.from_tensor_slices((eval_input_enc, eval_output_enc, eval_target_dec))
  dataset = dataset.shuffle(buffer_size = len(eval_input_enc)) 
  dataset = dataset.batch(batch_size)
  dataset = dataset.map(rearrange)
  dataset = dataset.repeat(1)
  iterator =dataset.make_one_shot_iterator()
  return iterator.get_next()

def rearrange(input, output, target):
  features = {'input':input, 'output':output}
  return features, target

# %% [markdown]
# * 모델의 예측은 배열로 생성되기 때문에 이를 확인하기 위해선 문자열로 변환이 필요
# * 예측을 문자열로 변환해주는 `pred2string()` 함수 선언

# %%
def pred2string(value,dictionary): 
  sentence_string = []
  is_finished = False
  
  for v in value :
    sentence_string = [dictionary[index] for index in v['indexs']]
    print(sentence_string)

  answer = ""
  for word in sentence_string:
    print(word)
    if word == END : #가저온 결과가 end 면 끝
      is_finished = True
      break

    if word != PAD and word != END:
      answer += word
      answer += " "

  return answer, is_finished

# %% [markdown]
#  https://github.com/songys/Chatbot_data.git

# %%
# !git clone https://github.com/songys/Chatbot_data.git
# Out:
# Cloning into 'Chatbot_data'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 57 (delta 21), reused 6 (delta 3), pack-reused 18
# Unpacking objects: 100% (57/57), done.

# %%
ls
# Out:
# Chatbot_data/  sample_data/

# %%
import pandas as pd
import re
import numpy as np

tokenize_as_morph = True 

data_path = 'Chatbot_data/ChatbotData.csv'

char2idx, idx2char, len_vocab = load_vocab(data_path) 
train_input, train_label, eval_input, eval_label = load_data(data_path)

# %%
print(char2idx)
print(idx2char)
# Out:
# {'<PADDING>': 0, '<START>': 1, '<END>': 2, '<UNKNOWN>': 3, '당연해요': 4, '갔을거예요': 5, '장이': 6, '막아': 7, '띵한게': 8, '침침해': 9, '그래도': 10, '3시': 11, '가원': 12, '급하게': 13, '밖에': 14, '야할까': 15, '지킴': 16, '막힌듯': 17, '자아': 18, '했다': 19, '된것': 20, '애매하다': 21, '나쁜말': 22, '개있나': 23, '음으로': 24, '서정': 25, '보고싶나': 26, '하고싶진': 27, '같았는데': 28, '두서': 29, '꿈꿨어요': 30, '이어가세요': 31, '들어가는': 32, '가봐요': 33, '질문': 34, '받고있는거네': 35, '달무': 36, '덕질': 37, '미래': 38, '중요하니까': 39, '재테크': 40, '티끌': 41, '그리워만': 42, '좋다고못': 43, '학용품': 44, '탈모': 45, '되고': 46, '달늘': 47, '되고나니': 48, '는다는': 49, '이넘었네': 50, '버리려': 51, '기숙': 52, '맙시': 53, '된대': 54, '즉흥': 55, '끝났다': 56, '재동': 57, '지쳐가': 58, '흘렀네': 59, '돌아가길': 60, '알아봤는데': 61, '한적한': 62, '그랬어요': 63, '중요한게': 64, '들어오면': 65, '나타났나': 66, '사겨야죠': 67, '차사': 68, '보낼려': 69, '치여': 70, '갈거예요': 71, '600일': 72, '블로그': 73, '넘었는데': 74, '해전': 75, '대보세요': 76, '싱숭생숭': 77, '든든하게': 78, '답답증': 79, '갔어': 80, '하는데실수를': 81, '평화': 82, '공기': 83, '친해지고싶어': 84, '붙잡는건': 85, '다행': 86, '느껴지지': 87, '근': 88, '담배': 89, '잡을수가': 90, '시켜야겠다': 91, '손수건': 92, '오르고있는줄': 93, '스타벅스': 94, '신하': 95, '내가있는': 96, '잊지못하고있나': 97, '막혀': 98, '깜': 99, '서운하지': 100, '이었네': 101, '여린': 102, '실망했어요': 103, '쐬고와': 104, '예쁠것': 105, '괴로워하시는군요': 106, '번또': 107, '자기애': 108, '챙기는거': 109, '불편해': 110, '볼수': 111, '불러야해': 112, '하려니까': 113, '가느냐가': 114, '집니다': 115, '껴': 116, '기대': 117, '꼈어': 118, '덜덜': 119, '등등': 120, '반의만남끝에헤어지게되었습니다': 121, '살려줘라는': 122, '상관없어요': 123, '독': 124, '간단하게': 125, '서막': 126, '받겠죠': 127, '백수': 128, '지우는': 129, '헤어져야겠죠': 130, '심부름': 131, '은줄': 132, '라는': 133, '들었어요': 134, '기제': 135, '기대합니다': 136, '넣을수있을거예요': 137, '당황': 138, '가혹하죠': 139, '신경': 140, '생겼': 141, '바뀔수있어요': 142, '있으니': 143, '땅': 144, '삭제': 145, '해줄거라': 146, '지켜볼수밖에': 147, '보여도': 148, '오늘날': 149, '키울수있을거예요': 150, '보고싶네': 151, '잡': 152, '시보': 153, '가봤는데': 154, '따라다니는': 155, '들려': 156, '있는데다': 157, '바꾸는': 158, '받았는데': 159, '돌아올거아는데': 160, '나갔길': 161, '세우지': 162, '내는게': 163, '생겼나': 164, '하는것을': 165, '자세히': 166, '간식': 167, '와야가는말도': 168, '오랫': 169, '힘들면': 170, '잊는게': 171, '않은거예요': 172, '그렇진': 173, '종교의자유': 174, '봐주러': 175, '일있으신': 176, '흔들림': 177, '달라졌겠죠': 178, '가리세요': 179, '강해지세요': 180, '게이': 181, '보란': 182, '30분': 183, '움직': 184, '더니': 185, '안되있을까': 186, '키우게해': 187, '차리고싶다': 188, '많을까': 189, '머좀': 190, '편하고요': 191, '남못': 192, '판단': 193, '대상': 194, '세탁기': 195, '그럴거': 196, '이냐에': 197, '패': 198, '쉽고': 199, '어장': 200, '감사': 201, '같은거야': 202, '얼떨떨할거예요': 203, '같길': 204, '돌아온': 205, '좋았을텐데': 206, '맞나': 207, '괴롭게만': 208, '아픈데': 209, '내꺼': 210, '드셔': 211, '챙기기': 212, '살아가고': 213, '있으니이해': 214, '성공': 215, '배려': 216, '이회': 217, '상이': 218, '이었어': 219, '신었는': 220, '할시': 221, '알았어': 222, '하게해': 223, 'ㅊ': 224, '사간대': 225, '발': 226, '헤어졌어': 227, '즐기실': 228, '위축': 229, '나쁜남자': 230, '나가면': 231, '그렇기': 232, '치료받아야하나': 233, '우좀': 234, '룸': 235, '거드세요': 236, '받고싶다': 237, '휘성': 238, '직못': 239, '궁금해지네': 240, '버렸네': 241, '언어': 242, '클수도': 243, '종종': 244, '솔로': 245, '날아가고싶어': 246, '즐거울텐데': 247, '헷갈릴': 248, '힘내라는': 249, '하고있다고': 250, '싸울까': 251, '끈이었을거예요': 252, '바이': 253, '참주말': 254, '억울한': 255, '당당하게나가세요': 256, '없을까봐': 257, '거창하지': 258, '망한거': 259, '설렜는데': 260, '가면': 261, '유지': 262, '후련한': 263, '달라지지': 264, '씌': 265, '끄라고': 266, '믿음': 267, '심어': 268, '사량': 269, '찍은것': 270, '이럴까': 271, '맞겠지': 272, '방법': 273, '의한다면': 274, '먹고싶아': 275, '기댈수있었으면': 276, '생겼다는대': 277, '잊어버리는것이': 278, '했더라': 279, '오르고': 280, '보지못': 281, '붙였나': 282, '면도기': 283, '냐': 284, '펴만': 285, '젠': 286, '바쁘게': 287, '들이있다는걸': 288, '지내니': 289, '폭망': 290, '있지만': 291, '좋은': 292, '무리해야': 293, '전환': 294, '힘든가': 295, '할줄': 296, '놀고하고': 297, '함께였을테니까': 298, '병': 299, '안주': 300, '분하고': 301, '얻는게': 302, '만나고있어': 303, '본다': 304, '헤어지려고': 305, '멍청하네': 306, '반함': 307, '붙': 308, '잘이나': 309, '무섭고': 310, '하려고하는데': 311, '스팸전화': 312, '가안': 313, '놓쳐서': 314, '그래오': 315, '자해': 316, '하겠습니다': 317, '헤어진대': 318, '예약': 319, '황당해': 320, '강제': 321, '연하': 322, '지친거': 323, '떠오르니까': 324, '크지': 325, '대화': 326, '지켜': 327, '싫어할': 328, '기다리지도': 329, '좋아하길': 330, '나타': 331, '젖었어': 332, '헤어진지오래': 333 ...
# {0: '<PADDING>', 1: '<START>', 2: '<END>', 3: '<UNKNOWN>', 4: '당연해요', 5: '갔을거예요', 6: '장이', 7: '막아', 8: '띵한게', 9: '침침해', 10: '그래도', 11: '3시', 12: '가원', 13: '급하게', 14: '밖에', 15: '야할까', 16: '지킴', 17: '막힌듯', 18: '자아', 19: '했다', 20: '된것', 21: '애매하다', 22: '나쁜말', 23: '개있나', 24: '음으로', 25: '서정', 26: '보고싶나', 27: '하고싶진', 28: '같았는데', 29: '두서', 30: '꿈꿨어요', 31: '이어가세요', 32: '들어가는', 33: '가봐요', 34: '질문', 35: '받고있는거네', 36: '달무', 37: '덕질', 38: '미래', 39: '중요하니까', 40: '재테크', 41: '티끌', 42: '그리워만', 43: '좋다고못', 44: '학용품', 45: '탈모', 46: '되고', 47: '달늘', 48: '되고나니', 49: '는다는', 50: '이넘었네', 51: '버리려', 52: '기숙', 53: '맙시', 54: '된대', 55: '즉흥', 56: '끝났다', 57: '재동', 58: '지쳐가', 59: '흘렀네', 60: '돌아가길', 61: '알아봤는데', 62: '한적한', 63: '그랬어요', 64: '중요한게', 65: '들어오면', 66: '나타났나', 67: '사겨야죠', 68: '차사', 69: '보낼려', 70: '치여', 71: '갈거예요', 72: '600일', 73: '블로그', 74: '넘었는데', 75: '해전', 76: '대보세요', 77: '싱숭생숭', 78: '든든하게', 79: '답답증', 80: '갔어', 81: '하는데실수를', 82: '평화', 83: '공기', 84: '친해지고싶어', 85: '붙잡는건', 86: '다행', 87: '느껴지지', 88: '근', 89: '담배', 90: '잡을수가', 91: '시켜야겠다', 92: '손수건', 93: '오르고있는줄', 94: '스타벅스', 95: '신하', 96: '내가있는', 97: '잊지못하고있나', 98: '막혀', 99: '깜', 100: '서운하지', 101: '이었네', 102: '여린', 103: '실망했어요', 104: '쐬고와', 105: '예쁠것', 106: '괴로워하시는군요', 107: '번또', 108: '자기애', 109: '챙기는거', 110: '불편해', 111: '볼수', 112: '불러야해', 113: '하려니까', 114: '가느냐가', 115: '집니다', 116: '껴', 117: '기대', 118: '꼈어', 119: '덜덜', 120: '등등', 121: '반의만남끝에헤어지게되었습니다', 122: '살려줘라는', 123: '상관없어요', 124: '독', 125: '간단하게', 126: '서막', 127: '받겠죠', 128: '백수', 129: '지우는', 130: '헤어져야겠죠', 131: '심부름', 132: '은줄', 133: '라는', 134: '들었어요', 135: '기제', 136: '기대합니다', 137: '넣을수있을거예요', 138: '당황', 139: '가혹하죠', 140: '신경', 141: '생겼', 142: '바뀔수있어요', 143: '있으니', 144: '땅', 145: '삭제', 146: '해줄거라', 147: '지켜볼수밖에', 148: '보여도', 149: '오늘날', 150: '키울수있을거예요', 151: '보고싶네', 152: '잡', 153: '시보', 154: '가봤는데', 155: '따라다니는', 156: '들려', 157: '있는데다', 158: '바꾸는', 159: '받았는데', 160: '돌아올거아는데', 161: '나갔길', 162: '세우지', 163: '내는게', 164: '생겼나', 165: '하는것을', 166: '자세히', 167: '간식', 168: '와야가는말도', 169: '오랫', 170: '힘들면', 171: '잊는게', 172: '않은거예요', 173: '그렇진', 174: '종교의자유', 175: '봐주러', 176: '일있으신', 177: '흔들림', 178: '달라졌겠죠', 179: '가리세요', 180: '강해지세요', 181: '게이', 182: '보란', 183: '30분', 184: '움직', 185: '더니', 186: '안되있을까', 187: '키우게해', 188: '차리고싶다', 189: '많을까', 190: '머좀', 191: '편하고요', 192: '남못', 193: '판단', 194: '대상', 195: '세탁기', 196: '그럴거', 197: '이냐에', 198: '패', 199: '쉽고', 200: '어장', 201: '감사', 202: '같은거야', 203: '얼떨떨할거예요', 204: '같길', 205: '돌아온', 206: '좋았을텐데', 207: '맞나', 208: '괴롭게만', 209: '아픈데', 210: '내꺼', 211: '드셔', 212: '챙기기', 213: '살아가고', 214: '있으니이해', 215: '성공', 216: '배려', 217: '이회', 218: '상이', 219: '이었어', 220: '신었는', 221: '할시', 222: '알았어', 223: '하게해', 224: 'ㅊ', 225: '사간대', 226: '발', 227: '헤어졌어', 228: '즐기실', 229: '위축', 230: '나쁜남자', 231: '나가면', 232: '그렇기', 233: '치료받아야하나', 234: '우좀', 235: '룸', 236: '거드세요', 237: '받고싶다', 238: '휘성', 239: '직못', 240: '궁금해지네', 241: '버렸네', 242: '언어', 243: '클수도', 244: '종종', 245: '솔로', 246: '날아가고싶어', 247: '즐거울텐데', 248: '헷갈릴', 249: '힘내라는', 250: '하고있다고', 251: '싸울까', 252: '끈이었을거예요', 253: '바이', 254: '참주말', 255: '억울한', 256: '당당하게나가세요', 257: '없을까봐', 258: '거창하지', 259: '망한거', 260: '설렜는데', 261: '가면', 262: '유지', 263: '후련한', 264: '달라지지', 265: '씌', 266: '끄라고', 267: '믿음', 268: '심어', 269: '사량', 270: '찍은것', 271: '이럴까', 272: '맞겠지', 273: '방법', 274: '의한다면', 275: '먹고싶아', 276: '기댈수있었으면', 277: '생겼다는대', 278: '잊어버리는것이', 279: '했더라', 280: '오르고', 281: '보지못', 282: '붙였나', 283: '면도기', 284: '냐', 285: '펴만', 286: '젠', 287: '바쁘게', 288: '들이있다는걸', 289: '지내니', 290: '폭망', 291: '있지만', 292: '좋은', 293: '무리해야', 294: '전환', 295: '힘든가', 296: '할줄', 297: '놀고하고', 298: '함께였을테니까', 299: '병', 300: '안주', 301: '분하고', 302: '얻는게', 303: '만나고있어', 304: '본다', 305: '헤어지려고', 306: '멍청하네', 307: '반함', 308: '붙', 309: '잘이나', 310: '무섭고', 311: '하려고하는데', 312: '스팸전화', 313: '가안', 314: '놓쳐서', 315: '그래오', 316: '자해', 317: '하겠습니다', 318: '헤어진대', 319: '예약', 320: '황당해', 321: '강제', 322: '연하', 323: '지친거', 324: '떠오르니까', 325: '크지', 326: '대화', 327: '지켜', 328: '싫어할', 329: '기다리지도', 330: '좋아하길', 331: '나타', 332: '젖었어', 333: '헤어진지오래' ...

# %%
print(len(train_input))
print(len(eval_input))
# Out:
# 7921
# 3902

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# * 앞서 작성한 트랜스포머 모델을 결합해 학습에 사용할 모델을 구성함

# %%
def build_model(features, labels, mode, params):

  TRAIN = mode == tf.estimator.ModeKeys.TRAIN
  EVAL = mode == tf.estimator.ModeKeys.EVAL
  PREDICT = mode == tf.estimator.ModeKeys.PREDICT

  position_encode = positional_encoding(params['embedding_size'], params['max_len'])
  if params['xavier_initializer']:
    embedding_initializer = 'glorot_normal'
  else :
    embedding_initializer = 'uniform'
  
  embedding = tf.keras.layers.Embedding(params['len_vocab'],
                                        params['embedding_size'],
                                        embeddings_initializer=embedding_initializer)
  
  x_embedded_matrix = embedding(features['input']) + position_encode
  y_embedded_matrix = embedding(features['output']) + position_encode

  encoder_outputs = encoder(x_embedded_matrix, params['model_hidden_size'], params['ffn_hidden_size'],
                            params['attention_head_size'], params['layer_size'])
  
  decoder_outputs = decoder(y_embedded_matrix, encoder_outputs, params['model_hidden_size'], params['ffn_hidden_size'],
                            params['attention_head_size'], params['layer_size'])
  
  logits = tf.keras.layers.Dense(params['len_vocab'])(decoder_outputs)
  predict = tf.argmax(logits, 2)

  if PREDICT :
    predictions = {'indexs' : predict,
                   'logits' : logits}
    return tf.estimator.EstimatorSpec(mode, predictions=predictions)

  labels_ = tf.one_hot(labels, params['len_vocab'])
  loss = tf.reduce_mean(tf.compat.v1.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=labels_))
  accuracy = tf.compat.v1.metrics.accuracy(labels=labels, predictions=predict)

  metrics = {'accuracy':accuracy}
  tf.summary.scalar('accuracy' , accuracy[1])

  if EVAL:
    return tf.estimator.EstimatorSpec(mode, loss=loss, eval_metric_ops=metrics)
  assert TRAIN

  optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=params['learning_rate'])
  train_op = optimizer.minimize(loss, global_step=tf.compat.v1.train.get_global_step())
  return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

# %% [markdown]
# ### 모델 학습

# %% [markdown]
# *   필요한 각종 인자들을 설정
# *   인자에 따라 학습 결과가 달라질 수 있기 때문에 세심한 조정이 필요

# %%
max_len = 25
epoch = 1000
batch_size =256
embedding_size = 100
model_hidden_size = 100
ffn_hidden_size = 100
attention_head_size = 100
lr = 0.001
layer_size =3
xavier_initializer = True

# %% [markdown]
# *   앞서 선언한 processing 함수로 데이터를 모델에 투입할 수 있도록 가공
# *   평가 데이터에도 동일하게 가공

# %%
train_input_enc, train_input_enc_length = enc_processing(train_input, char2idx)
train_output_dec, train_output_dec_length = dec_output_processing(train_label, char2idx)
train_target_dec = dec_target_processing(train_label, char2idx)

# %%
eval_input_enc, eval_input_enc_length = enc_processing(eval_input, char2idx)
eval_output_dec, eval_output_dec_length = dec_output_processing(eval_label, char2idx)
eval_target_dec = dec_target_processing(eval_label, char2idx)

# %% [markdown]
# * 앞서 선언한 함수를 통해 모델을 선언하고 학습
# * `tf.estimator`를 사용해 간편하게 학습 모듈 구성

# %%
transformer = tf.estimator.Estimator(
  model_fn = build_model,
  params = {'embedding_size' : embedding_size,
            'model_hidden_size':model_hidden_size,
            'ffn_hidden_size':ffn_hidden_size,
            'attention_head_size':attention_head_size,
            'learning_rate':lr,
            'len_vocab':len_vocab,
            'layer_size':layer_size,
            'max_len':max_len,
            'xavier_initializer':xavier_initializer
  }
)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp0k4ri0om
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp0k4ri0om', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# * 학습한 모델을 사용해 챗봇을 사용
# * 예측 결과를 문자열로 변환할 때는 앞서 선언한 `pred2string()` 함수를 이용
# * 입력에 대한 응답이 생성되는 것을 확인할 수 있음

# %%
transformer.train(input_fn = lambda : train_input_fn(train_input_enc, train_output_dec,train_target_dec,batch_size),steps=epoch)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From <ipython-input-18-03ec5d33c9d2>:7: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# This is a deprecated API that should only be used in TF 1 graph mode and legacy TF 2 graph mode available through `tf.compat.v1`. In all other situations -- namely, eager mode and inside `tf.function` -- you can consume dataset elements using `for elem in dataset: ...` or by explicitly creating iterator via `iterator = iter(dataset)` and fetching its elements via `values = next(iterator)`. Furthermore, this API is not available in TF 2. During the transition from TF 1 to TF 2 you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)` to create a TF 1 graph mode style iterator for a dataset created through TF 2 APIs. Note that this should be a transient state of your code base as there are in general no guarantees about the interoperability of TF 1 and TF 2 code.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp0k4ri0om/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 9.660397, step = 0
# INFO:tensorflow:global_step/sec: 5.71855
# INFO:tensorflow:loss = 6.123282, step = 100 (17.494 sec)
# INFO:tensorflow:global_step/sec: 6.71981
# INFO:tensorflow:loss = 1.2779577, step = 200 (14.880 sec)
# INFO:tensorflow:global_step/sec: 6.85245
# INFO:tensorflow:loss = 1.264462, step = 300 (14.594 sec)
# INFO:tensorflow:global_step/sec: 6.86746
# INFO:tensorflow:loss = 1.2778187, step = 400 (14.561 sec)
# INFO:tensorflow:global_step/sec: 6.875
# INFO:tensorflow:loss = 1.2417612, step = 500 (14.545 sec)
# INFO:tensorflow:global_step/sec: 6.84863
# INFO:tensorflow:loss = 1.2061535, step = 600 (14.602 sec)
# INFO:tensorflow:global_step/sec: 6.81005
# INFO:tensorflow:loss = 1.2769678, step = 700 (14.684 sec)
# INFO:tensorflow:global_step/sec: 6.82737
# INFO:tensorflow:loss = 1.2579868, step = 800 (14.647 sec)
# INFO:tensorflow:global_step/sec: 6.86466
# INFO:tensorflow:loss = 1.245825, step = 900 (14.567 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp0k4ri0om/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 1.2493732.

# %%
eval_result = transformer.evaluate(input_fn = lambda : eval_input_fn(eval_input_enc, eval_output_dec,eval_target_dec,batch_size))
print(eval_result)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-06-07T08:35:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp0k4ri0om/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 3.21069s
# INFO:tensorflow:Finished evaluation at 2022-06-07-08:35:56
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.8112865, global_step = 1000, loss = 1.3071265
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmp0k4ri0om/model.ckpt-1000
# {'accuracy': 0.8112865, 'loss': 1.3071265, 'global_step': 1000}
